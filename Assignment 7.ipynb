# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experience_coding  25973 non-null  float64
#  1   python_user        25973 non-null  bool
#  2   r_user             25973 non-null  bool
#  3   sql_user           25973 non-null  bool
#  4   most_used          16835 non-null  object
#  5   compensation       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
df = df[1:]
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# 5                    1.0         True   False     False       PyTorch
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 1            236889
# 2             74321
# 3             62593
# 4             36288
# ...

# %%
df.describe()
# Out:
#        experience_coding  compensation
# count       25972.000000  2.597200e+04
# mean            5.297201  5.325008e+04
# std             6.898282  8.008257e+04
# min             0.000000  0.000000e+00
# 25%             0.947500  7.700250e+03
# 50%             2.500000  5.400850e+04
# 75%             6.000000  6.747700e+04
# max            30.000000  1.492951e+06

# %%
df.describe(include='all')
# Out:
#         experience_coding python_user r_user sql_user     most_used  \
# count        25972.000000       25972  25972    25972         16834
# unique                NaN           2      2        2             4
# top                   NaN        True  False    False  Scikit-learn
# freq                  NaN       21859  20637    15216          7933
# mean             5.297201         NaN    NaN      NaN           NaN
# std              6.898282         NaN    NaN      NaN           NaN
# min              0.000000         NaN    NaN      NaN           NaN
# 25%              0.947500         NaN    NaN      NaN           NaN
# 50%              2.500000         NaN    NaN      NaN           NaN
# 75%              6.000000         NaN    NaN      NaN           NaN
# max             30.000000         NaN    NaN      NaN           NaN
#
#         compensation
# count   2.597200e+04
# unique           NaN
# top              NaN
# freq             NaN
# mean    5.325008e+04
# ...

# %%
df.experience_coding = df.experience_coding.replace('Nan',0).astype(float)
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# 5                    1.0         True   False     False       PyTorch
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 1            236889
# 2             74321
# 3             62593
# 4             36288
# ...

# %%
df.compensation.min()
# Out:
# 0

# %%
df.compensation.max()
# Out:
# 1492951
